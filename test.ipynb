# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
lst = [[1,2,3,4],[2,3,4,4],[3,4,3,2],[3,4,5,6],[5,7,5,2]]
label = ["mot","hai","ba","bon"]
df = pd.DataFrame(lst,columns=label)
df
# Out:
#    mot  hai  ba  bon
# 0    1    2   3    4
# 1    2    3   4    4
# 2    3    4   3    2
# 3    3    4   5    6
# 4    5    7   5    2

# %%
sb.scatterplot(x=df.mot,y=df.hai)
# Out:
# <AxesSubplot:xlabel='mot', ylabel='hai'>
